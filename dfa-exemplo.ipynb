# %%
from dfa import DFA
Q = {'q0','q1','q2'}
Sigma = {'0','1'}
q0 = 'q0'
delta = {
    ('q0','0'):'q1',
    ('q0','1'):'q0',
    ('q1','0'):'q1',
    ('q1','1'):'q2',
    ('q2','0'):'q2',
    ('q2','1'):'q2',
}
F = {'q2'}
Dx01y = DFA(Q,Sigma,q0,delta,F)
Dx01y.visualizar()
